# %% [markdown]
# # Linear Regression Model
# <h3><i>The Normal Equation</i></h3>

# %%
import numpy as np
np.random.seed(42) # to make this code example reproducible
m = 100 # number of instances
X = 2 * np.random.rand(m, 1) # column vector
y = 4 + 3 * X + np.random.randn(m, 1) # column vector

# %%
from sklearn.preprocessing import add_dummy_feature
x_b = add_dummy_feature(X) # add X0 = 1 to each instance
theta_best = np.linalg.inv(x_b.T @ x_b) @ x_b.T @ y # the @ operator performs matrics multiplication

# %%
theta_best
# Out:
# array([[4.21509616],
#        [2.77011339]])

# %%
# making prediction using 𝛉:
X_new  = np.array([[0], [2]])
X_new_b = add_dummy_feature(X_new) # add X0 = 1 to each instance
y_predict = X_new_b @ theta_best
y_predict
# Out:
# array([[4.21509616],
#        [9.75532293]])

# %%
# plotting the model for better visualization
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 7))
plt.plot(X_new, y_predict, "r-", label="predictions")
plt.plot(X,y, "b.")
plt.xlabel("X1", f=15)
plt.ylabel("y", rotation=0)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 8
#       6 plt.xlabel("X1")
#       7 plt.ylabel("y", rotation=0)
# ----> 8 plt.xticks(figsize=15)
#       9 plt.legend()
#      10 plt.show()
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/matplotlib/pyplot.py:2227, in xticks(ticks, labels, minor, **kwargs)
#    2225     labels_out = ax.get_xticklabels(minor=minor)
#    2226     for l in labels_out:
# -> 2227         l._internal_update(kwargs)
#    2228 else:
#    2229     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/matplotlib/artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File /usr/local/Cellar/jupyterlab/4.2.3/libexec/lib/python3.12/site-packages/matplotlib/artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Text.set() got an unexpected keyword argument 'figsize'
